# %%
import torch
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path= 'img.jpg'

# %%
reader= easyocr.Reader(['en'],gpu=False)
result = reader.readtext(img_path)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# /home/sooraj/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and will be removed in 0.15. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# /home/sooraj/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/sooraj/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# [([[148, 240], [1153, 240], [1153, 333], [148, 333]],
#   'How to write references',
#   0.9965848378467622),
#  ([[141, 342], [1150, 342], [1150, 468], [141, 468]],
#   'that people understand',
#   0.6770516067485516)]

# %% [markdown]
# ##Now we need to visualize it

# %%
img=cv2.imread(img_path)
for detection in result:
    top_left=tuple([int(val) for val in detection[0][0]])
    bottom_right=tuple([int(val) for val in detection[0][2]])
    text= detection[1]
    font=cv2.FONT_HERSHEY_SIMPLEX
    img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
    img=cv2.putText(img,text,top_left,font,.5,(255,125,255),2,cv2.LINE_AA)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
for i in result:
    print(i[1])
# Out:
# How to write references
# that people understand
